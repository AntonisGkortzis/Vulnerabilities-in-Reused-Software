# %% [markdown]
# <a id="dc-index"></a>
# # Data Collection for RQ3-RQ4, Gkortzis et al. - JSS'19 Special Issue on Software and Systems Reuse in the Big Data Era
#
# This notebook performs the following processes for answering RQ3 and RQ4:
#
# 1. [Run OWASP dependency checker tool](#run_owasp)
# 2. [Libraries reuse frequencies](#frequency)
# 3. [Parse OWASP vulnerabilities](#parse_owasp)
# 4. [Spotbugs on Dependencies](#spotbugs_dependencies)
# 5. [Detect 'dependency' projects](#dependencies_projects)

# %% [markdown]
# <a id='run_owasp'></a>
# ## Run OWASP dependency checker tool
#
# This script executes __owasp dependency checker tool__ on a list of jar files. If the list is not provided, the tool will generate it on its own, based on the given _root directory_ variable. If you want to provide the list, use the following command:
# ```
# find path_to_root_directory -name '*.jar' -or -name '*.war'
# ```
# __Important__:
# 1. Note that the final file should store the findings with their absolute path.
# 2. This analysis might take hours or days to complete. You might consider parallelizing it by splitting the jar_list into smaller lists and analyze them in parallel.
#
# You can download the already generated owasp reports from [here](https://send.firefox.com/download/5cd259cabe1ad54a/#FtNsrxrTFGDA9g1Xzik7Zg).
#
# [Back to table of contents](#dc-index)

# %%
import datetime
import logging
import os
import owasp_dependency_analyzer as owasp

logging.basicConfig(level=logging.DEBUG)

os.chdir('/home/agkortzis/git_repos/ICSR19/analysis/tooling')
os.getcwd()
root_directory = '/media/agkortzis/Data/m2/repository'
owasp_executable = './vendor/dependency-check/bin/dependency-check.sh'
output_dir = '/media/agkortzis/Data/owasp_reports'
jar_list = '../local-jars_clean.txt'
report_format = 'JSON'

currentDT = datetime.datetime.now()
print ("Started at :: {}".format(str(currentDT)))    

owasp.execute(root_directory, owasp_executable, jar_list, output_dir, report_format)

currentDT = datetime.datetime.now()
print ("Finished at :: {}".format(str(currentDT)))

# %% [markdown]
# <a id="frequency"></a>
# ## Libraries reuse frequencies
#
# The following script counts the appearence of each dependency in a set of given Maven .trees files, as produced by Step '4. Retrieve project dependencies' in the DataCollection notebook. It produces a file with entries like the following:
#
# _library;number of uses;projects used in_
#
# [Back to table of contents](#dc-index)

# %%
import os
import logging
import datetime

import maven

logging.basicConfig(level=logging.INFO)

def parse_trees(path_to_data, path_to_m2, dependency_usages_output_file):
    dependency_usage = {}
    projects_tress = [f for f in os.listdir(path_to_data) if f.endswith('.trees')]
    total = len(projects_tress)
    for index, f in enumerate(projects_tress):
        file_project_trees = os.path.join(path_to_data, f)
        project_name = f.replace('.trees','')
        logging.info("{}/{} :: {} (tree={})".format(index,total,project_name,file_project_trees))

        trees = maven.get_compiled_modules(file_project_trees)

        if not trees:
            logging.info(f'No modules to analyze: {file_project_trees}.')
            continue

        modules = [m.artifact for m in trees]
        dep_modules = [m.artifact for t in trees for m in t.deps if m.artifact not in modules]
        dep_modules = list(set(dep_modules)) # remove duplicates
#         pkg_paths = []
#         for t in trees:
            
#             pkg_paths.extend([a.artifact.get_m2_path().replace(path_to_m2, '').replace('/','_') for a in t])

#         pkg_paths = list(set(pkg_paths))
        for module in dep_modules:
            dependency = module.get_m2_path(path_to_m2).replace(path_to_m2, '').replace('/','_')
            if dependency in dependency_usage:
                dependency_usage[dependency].append(project_name)
            else:
                dependency_usage[dependency] = [project_name]

    # write results to file
    with open(dependency_usages_output_file, 'w') as f:
        seperator = ';'
        for dependency in dependency_usage:
            f.write("{}{}{}{}{}\n".format(dependency,seperator,len(dependency_usage[dependency]),seperator,seperator.join(dependency_usage[dependency])))
    
    return dependency_usage
            
os.chdir('/home/agkortzis/git_repos/ICSR19/analysis/tooling')
os.getcwd()
path_to_data = os.path.abspath('../repositories_data') #TODO: replace with relative
path_to_m2 = '/media/agkortzis/Data/m2/repository/'
dependency_usages_output_file = '../depependencies_usages_temp.csv'

currentDT = datetime.datetime.now()
print ("Started at :: {}".format(str(currentDT)))            

dependency_usages = parse_trees(path_to_data, path_to_m2, dependency_usages_output_file)

currentDT = datetime.datetime.now()
print ("Finished at :: {}".format(str(currentDT)))

for dependency in dependency_usages:
    logging.info("Dependency :: {} Usages :: {}".format(dependency,len(dependency_usage[dependency])))

# %% [markdown]
# <a id="parse_owasp"></a>
# ## Parse OWASP vulnerabilities
#
# This script parses the reports that owasp dependency checker tool created for each library in an earlier step of the analysis. It produces a file that contains an entry like the following:
#
# _jar or war;number of vulnerabilities_
#
# __Important__: Note that the output list contains also the produced jars/wars when Maven projects are build. Thus, It should be filtered to include only the 'dependencies' jars/wars.
#
# [Back to table of contents](#dc-index)

# %%
import datetime
import json
import logging
import os

logging.basicConfig(level=logging.INFO)


os.chdir('/home/agkortzis/git_repos/ICSR19/analysis/tooling')
os.getcwd()
path_to_owasp_reports = '/media/agkortzis/Data/owasp_reports/owasp_reports'
owasp_vulnerabilities = '../owasp_vulnerabilities_enhanced.csv'

def parse_owasp_reports(path_to_owasp_reports, owasp_vulnerabilities):
    logging.info("Pasing owasp reports.. This might take a while.")
    deps_vulnerabilities = {}
    deps_java_vulnerabilities = {}
    
    entries = os.listdir(path_to_owasp_reports)
    total = len(entries)
    for index, entry in enumerate(entries):
#         logging.debug("{}/{} :: Analyzing {}".format(index,total,entry))
        report = os.path.join(path_to_owasp_reports, entry, "dependency-check-report.json")
        if not os.path.exists(report):
            logging.error("{} does not exist".format(report))
            continue
        
        CVEs = set()
        java_cves = set()
        # Open the JSON
        with open(report) as json_file:
            data = json.load(json_file)
            
            # Retrieve vulnerabilities
            dependencies = data['dependencies']
            for dependency in dependencies:
#                 logging.info("Dependency filepath = {}".format(dependency['filePath']))
                if 'vulnerabilities' in dependency:
                    for cve in dependency['vulnerabilities']:
                        CVEs.add(cve['name'])
                        # count only cves in java dependencies
                        if dependency['filePath'].endswith('.jar'):
                            java_cves.add(cve['name']) 
        
        # Make entry library;number_of_vulnerabilities;number_of_java_vulnerabilities;cves_entries;java_cves_entries
        deps_vulnerabilities[entry] = [len(CVEs),len(java_cves),','.join(CVEs),','.join(java_cves)]
    
        # logging.debug("{};{};{}".format(entry,deps_vulnerabilities[entry][0],deps_vulnerabilities[entry][1]))
            
    logging.info("Writting results to file {}".format(owasp_vulnerabilities))
    with open(owasp_vulnerabilities, 'w') as f:
        for entry in deps_vulnerabilities:
            f.write("{};{};{};{};{}\n".format(entry,deps_vulnerabilities[entry][0],deps_vulnerabilities[entry][1],deps_vulnerabilities[entry][2],deps_vulnerabilities[entry][3]))
        
currentDT = datetime.datetime.now()
print ("Started at :: {}".format(str(currentDT)))            

parse_owasp_reports(path_to_owasp_reports, owasp_vulnerabilities)

currentDT = datetime.datetime.now()
print ("Finished at :: {}".format(str(currentDT)))
# Out:
# INFO:root:Pasing owasp reports.. This might take a while.
# Started at :: 2019-10-18 09:55:37.627346
# ERROR:root:/media/agkortzis/Data/owasp_reports/owasp_reports/owasp_reports/dependency-check-report.json does not exist
# INFO:root:Writting results to file ../owasp_vulnerabilities_enhanced.csv
# Finished at :: 2019-10-18 10:41:21.156258

# %% [markdown]
# <a id="spotbugs_dependencies"></a>
# ## Spotbugs on Dependencies
#
# In this step we parse each .trees file for projects and analyze their dependencies with Spotbugs.
# The output of this step is a file that contains the number of potential vulnerabilities for each dependency.
#
# [Back to table of contents](#dc-index)

# %%
import os
import logging
import datetime
import subprocess
from utility import Utility

import maven
import spotbugs

logging.basicConfig(level=logging.INFO)

def parse_spotbugs_xml(path_to_file):
    output = 0
    #logging.info("Analyzing file={}".format(path_to_file))
    
    p1 = subprocess.Popen(["grep","<BugInstance", path_to_file], stdout=subprocess.PIPE)
    p2 = subprocess.Popen(["wc", "-l"], stdin=p1.stdout, stdout=subprocess.PIPE)
    p1.stdout.close()  # Allow p1 to receive a SIGPIPE if p2 exits.
    output = p2.communicate()[0].decode('utf-8')
    
    #logging.info("Result={}".format(output))
    
    return output

    
def parse_trees_with_spotbugs(path_to_data, path_to_m2, dependency_vulnerabilities_output_file):
    dependency_vulnerabilities = {}
    projects_tress = [f for f in os.listdir(path_to_data) if f.endswith('.trees')]
    total = len(projects_tress)
    for index, f in enumerate(projects_tress):
        file_project_trees = os.path.join(path_to_data, f)
        project_name = f.replace('.trees','')
        logging.info("{}/{} :: {}".format(index,total,project_name))

        trees = maven.get_compiled_modules(file_project_trees)

        if not trees:
            logging.info(f'No modules to analyze: {file_project_trees}.')
            continue

        modules = [m.artifact for m in trees]
        dep_modules = [m.artifact for t in trees for m in t.deps if m.artifact not in modules]
        dep_modules = list(set(dep_modules)) # remove duplicates

        for module in dep_modules:
            dependency = module.get_m2_path(path_to_m2)
            #logging.info("Dependency with path={}".format(dependency))
            spotbugs_file = "{}.spotbugs.xml".format(os.path.splitext(dependency)[0])
            
            overwrite = False
            spotbugs.analyze_project([dependency], spotbugs_file, overwrite)

            # parse spotbugs file here
            vulnerabilities = parse_spotbugs_xml(spotbugs_file)
       
            dependency_name = dependency.replace(path_to_m2, '').replace('/','_')
            logging.info("Result = {}::{}".format(dependency_name,vulnerabilities))
            dependency_vulnerabilities[dependency_name] = vulnerabilities
                   
    # write results to file
    with open(dependency_vulnerabilities_output_file, 'w') as f:
        seperator = ';'
        for dependency in dependency_vulnerabilities:
            f.write("{}{}{}\n".format(dependency,seperator,dependency_vulnerabilities[dependency]))
    
            
os.chdir('/home/agkortzis/git_repos/ICSR19/analysis/tooling/')
os.getcwd()
path_to_data = os.path.abspath('../repositories_data') #TODO: replace with relative
path_to_m2 = '/media/agkortzis/Data/m2/repository/'
dependency_vulnerabilities_output_file = '../depependencies_spotbugs.csv'

currentDT = datetime.datetime.now()
print ("Started at :: {}".format(str(currentDT)))            

parse_trees_with_spotbugs(path_to_data, path_to_m2, dependency_vulnerabilities_output_file)

currentDT = datetime.datetime.now()
print ("Finished at :: {}".format(str(currentDT)))

# %% [markdown]
# <a id="dependencies_projects"></a>
# ## Detect 'dependency' project
#
# In this step we identify projects that are used as dependencies in other projects. We want to exclude those projects from the analysis.
#
# [Back to table of contents](#dc-index)

# %%
import datetime
import logging
import os

import maven

logging.basicConfig(level=logging.INFO)

def detect_dependencies(path_to_data, path_to_m2, projects_as_dependencies_output_file):
    dependencies = []
    main_modules = {}
    projects_as_dependencies = set()
    projects_tress = [f for f in os.listdir(path_to_data) if f.endswith('.trees')]
    total = len(projects_tress)
    logging.info("Found {} tree files".format(total))
    
    for index, f in enumerate(projects_tress):
        file_project_trees = os.path.join(path_to_data, f)
        project_name = f.replace('.trees','')
        logging.info("{}/{} :: {})".format(index,total,project_name))

        trees = maven.get_compiled_modules(file_project_trees)

        if not trees:
            logging.info(f'No modules to analyze: {file_project_trees}.')
            continue

        modules = [m.artifact for m in trees]
        dep_modules = [m.artifact for t in trees for m in t.deps if m.artifact not in modules]
        # add deps to total one
        dependencies.extend([module.get_m2_path(path_to_m2) for module in dep_modules])
        for main_mod in modules:
            main_modules[main_mod.get_m2_path(path_to_m2)] = project_name
        
    
    dependencies = list(set(dependencies)) # remove duplicates   
    # detect main_modules in dependencies
    for main_mod in main_modules:
            if main_mod in dependencies:
                projects_as_dependencies.add(main_modules[main_mod])
                
    # write results to file
    with open(projects_as_dependencies_output_file, 'w') as f:
        for project in projects_as_dependencies:
            f.write("{}\n".format(project))
                    
    return projects_as_dependencies

os.chdir('/home/agkortzis/git_repos/ICSR19/analysis/tooling/')
os.getcwd()
path_to_data = os.path.abspath('../repositories_data') #TODO: replace with relative
path_to_m2 = "/media/agkortzis/Elements/maven_m2"
projects_as_dependencies_output_file = '../projects_as_dependencies.csv'

currentDT = datetime.datetime.now()
print ("Started at :: {}".format(str(currentDT)))            

projects_as_dependencies = detect_dependencies(path_to_data, path_to_m2, projects_as_dependencies_output_file)
print("Found {} projects as dependencies".format(len(projects_as_dependencies)))

currentDT = datetime.datetime.now()
print ("Finished at :: {}".format(str(currentDT)))
# Out:
# INFO:root:Found 2279 tree files
# INFO:root:0/2279 :: wcrasta.TwitterBoost-Tools)
# INFO:root:1/2279 :: jackyhung.consumer-dispatcher)
# INFO:root:2/2279 :: mdeverdelhan.ta4j)
# INFO:root:3/2279 :: lviggiano.owner)
# INFO:root:4/2279 :: gwtd3.gwt-d3)
# INFO:root:5/2279 :: Hive2Hive.Hive2Hive)
# INFO:root:6/2279 :: MutabilityDetector.MutabilityDetector)
# INFO:root:7/2279 :: bfwg.angular-spring-starter)
# INFO:root:8/2279 :: httl.httl)
# INFO:root:9/2279 :: hortonworks-spark.shc)
# INFO:root:10/2279 :: tranchis.xsd2thrift)
# INFO:root:11/2279 :: rsertelon.android-keystore-recovery)
# INFO:root:12/2279 :: linkedin.ml-ease)
# INFO:root:13/2279 :: mysecureshell.mysecureshell)
# INFO:root:14/2279 :: kloiasoft.eventapis)
# Started at :: 2019-10-22 22:40:41.597849
# INFO:root:15/2279 :: oxo42.stateless4j)
# INFO:root:No modules to analyze: /home/agkortzis/git_repos/ICSR19/analysis/repositories_data/oxo42.stateless4j.trees.
# INFO:root:16/2279 :: jingwei.krati)
# INFO:root:No modules to analyze: /home/agkortzis/git_repos/ICSR19/analysis/repositories_data/jingwei.krati.trees.
# INFO:root:17/2279 :: atomiqio.atomiq)
# INFO:root:18/2279 :: RepreZen.KaiZen-OpenAPI-Editor)
# INFO:root:No modules to analyze: /home/agkortzis/git_repos/ICSR19/analysis/repositories_data/RepreZen.KaiZen-OpenAPI-Editor.trees.
# INFO:root:19/2279 :: streamsets.datacollector)
# ERROR:maven:File is malformed: /home/agkortzis/git_repos/ICSR19/analysis/repositories_data/streamsets.datacollector.trees
# INFO:root:No modules to analyze: /home/agkortzis/git_repos/ICSR19/analysis/repositories_data/streamsets.datacollector.trees.
# INFO:root:20/2279 :: tbroyer.gwt-maven-archetypes)
# INFO:root:No modules to analyze: /home/agkortzis/git_repos/ICSR19/analysis/repositories_data/tbroyer.gwt-maven-archetypes.trees.
# INFO:root:21/2279 :: yujiasun.Distributed-Kit)
# INFO:root:22/2279 :: lukehutch.fast-classpath-scanner)
# INFO:root:23/2279 :: flex-users.flexlib)
# INFO:root:No modules to analyze: /home/agkortzis/git_repos/ICSR19/analysis/repositories_data/flex-users.flexlib.trees.
# INFO:root:24/2279 :: RobotiumTech.robotium)
# INFO:root:25/2279 :: essentials4j.essentials4j)
# INFO:root:26/2279 :: yuchenggroup.rapid-generator)
# INFO:root:27/2279 :: davidmoten.rxjava2-extras)
# INFO:root:28/2279 :: cheng-li.pyramid)
# INFO:root:29/2279 :: indeedeng.proctor)
# INFO:root:30/2279 :: pagehelper.pagehelper-spring-boot)
# INFO:root:31/2279 :: progrium.buildstep)
# INFO:root:32/2279 :: lambdista.try)
# INFO:root:33/2279 :: oukingtim.king-admin)
# INFO:root:34/2279 :: tmorcinek.android-codegenerator-library)
# INFO:root:35/2279 :: damnhandy.Handy-URI-Templates)
# INFO:root:No modules to analyze: /home/agkortzis/git_repos/ICSR19/analysis/repositories_data/damnhandy.Handy-URI-Templates.trees.
# INFO:root:36/2279 :: xetorthio.johm)
# INFO:root:37/2279 :: Syncleus.Ferma)
# INFO:root:38/2279 :: ngageoint.geowave)
# INFO:root:39/2279 :: carrotsearch.smartsprites)
# INFO:root:40/2279 :: Cue.greplin-bloom-filter)
# INFO:root:41/2279 :: hoijui.JavaOSC)
# INFO:root:42/2279 :: droolsjbpm.droolsjbpm-knowledge)
# INFO:root:No modules to analyze: /home/agkortzis/git_repos/ICSR19/analysis/repositories_data/droolsjbpm.droolsjbpm-knowledge.trees.
# INFO:root:43/2279 :: jpenren.thymeleaf-spring-data-dialect)
# INFO:root:44/2279 :: arun-gupta.kubernetes-aws-workshop)
# INFO:root:45/2279 :: mateuszk87.BadIntent)
# INFO:root:46/2279 :: usc-isi-i2.Web-Karma)
# INFO:root:47/2279 :: cerberustesting.cerberus-source)
# INFO:root:48/2279 :: vznet.mongo-jackson-mapper)
# INFO:root:49/2279 :: WantedTechnologies.xpresso)
# INFO:root:50/2279 :: essepuntato.rash)
# INFO:root:51/2279 :: zbra-solutions.android-linq)
# INFO:root:52/2279 :: openhab.openhab)
# INFO:root:No modules to analyze: /home/agkortzis/git_repos/ICSR19/analysis/repositories_data
plugin)
# INFO:root:No modules to analyze: /home/agkortzis/git_repos/ICSR19/analysis/repositories_data/sap-production.xcode-maven-plugin.trees.
# INFO:root:263/2279 :: ktoso.maven-git-commit-id-plugin)
# ERROR:maven:File is malformed: /home/agkortzis/git_repos/ICSR19/analysis/repositories_data/ktoso.maven-git-commit-id-plugin.trees
# INFO:root:No modules to analyze: /home/agkortzis/git_repos/ICSR19/analysis/repositories_data/ktoso.maven-git-commit-id-plugin.trees.
# INFO:root:264/2279 :: arquillian.arquillian-extension-persistence)
# INFO:root:265/2279 :: kevin-wayne.algs4)
# INFO:root:266/2279 :: google.mug)
# INFO:root:267/2279 :: pinterest.pinlater)
# INFO:root:268/2279 :: eBay.xcelite)
# INFO:root:269/2279 :: samczsun.Skype4J)
# INFO:root:270/2279 :: igniterealtime.Spark)
# INFO:root:271/2279 :: rjo1970.dumbster)
# INFO:root:272/2279 :: sryza.spark-ts-examples)
# INFO:root:273/2279 :: xnlogic.pacer)
# INFO:root:274/2279 :: TakahikoKawasaki.nv-i18n)
# INFO:root:No modules to analyze: /home/agkortzis/git_repos/ICSR19/analysis/repositories_data/TakahikoKawasaki.nv-i18n.trees.
# INFO:root:275/2279 :: grumlimited.geocalc)
# INFO:root:276/2279 :: jitsi.jicofo)
# INFO:root:277/2279 :: IDPF.epubcheck)
# INFO:root:278/2279 :: stuartsierra.clojure-hadoop)
# INFO:root:279/2279 :: aragozin.jvm-tools)
# INFO:root:280/2279 :: spotify.async-google-pubsub-client)
# INFO:root:281/2279 :: gravitee-io.gateway)
# INFO:root:282/2279 :: RepreZen.SwagEdit)
# INFO:root:No modules to analyze: /home/agkortzis/git_repos/ICSR19/analysis/repositories_data/RepreZen.SwagEdit.trees.
# INFO:root:283/2279 :: capergroup.bayou)
# INFO:root:No modules to analyze: /home/agkortzis/git_repos/ICSR19/analysis/repositories_data/capergroup.bayou.trees.
# INFO:root:284/2279 :: toomanyopenfiles.jmxmon)
# INFO:root:285/2279 :: spring-cloud.spring-cloud-config)
# INFO:root:286/2279 :: JakeWharton.retrofit1-okhttp3-client)
# INFO:root:287/2279 :: micromata.javaapiforkml)
# INFO:root:288/2279 :: Ardesco.selenium-standalone-server-plugin)
# ERROR:maven:File is malformed: /home/agkortzis/git_repos/ICSR19/analysis/repositories_data/Ardesco.selenium-standalone-server-plugin.trees
# INFO:root:No modules to analyze: /home/agkortzis/git_repos/ICSR19/analysis/repositories_data/Ardesco.selenium-standalone-server-plugin.trees.
# INFO:root:289/2279 :: JornC.bitcoin-transaction-explorer)
# INFO:root:290/2279 :: denisk20.programmer-dvorak)
# INFO:root:291/2279 :: opendatagroup.hadrian)
# INFO:root:292/2279 :: ElektraInitiative.libelektra)
# INFO:root:293/2279 :: jscep.jscep)
# INFO:root:294/2279 :: ghillairet.emfjson)
# INFO:root:No modules to analyze: /home/agkortzis/git_repos/ICSR19/analysis/repositories_data/ghillairet.emfjson.trees.
# INFO:root:295/2279 :: Yubico.ykneo-openpgp)
# INFO:root:No modules to analyze: /home/agkortzis/git_repos/ICSR19/analysis/repositories_data/Yubico.ykneo-openpgp.trees.
# INFO:root:296/2279 :: Codingpedia.demo-rest-jersey-spring)
# INFO:root:297/2279 :: TheCoder4eu.BootsFaces-OSP)
# INFO:root:298/2279 :: NewEconomyMovement.nem.core)
# INFO:root:299/2279 :: liygheart.jfinalbbs)
# INFO:root:300/2279 :: binaryfoo.emv-bertlv)
# INFO:root:301/2279 :: TNG.JGiven)
# ERROR:maven:File is malformed: /home/agkortzis/git_repos/ICSR19/analysis/repositories_data/TNG.JGiven.trees
# INFO:root:No modules to analyze: /home/agkortzis/git_repos/ICSR19/analysis/repositories_data/TNG.JGiven.trees.
# INFO:root:302/2279 :: statefulj.statefulj)
# INFO:root:303/2279 :: dianbaer.grain)
# INFO:root:304/2279 :: square.pollexor)
# INFO:root:305/2279 :: gwt-maven-plugin.gwt-maven-plugin)
# ERROR:maven:File is malformed: /home/agkortzis/git_repos/ICSR19/analysis/repositories_data
# INFO:root:358/2279 :: sematext.HBaseWD)
# INFO:root:359/2279 :: spinscale.elasticsearch-opennlp-plugin)
# INFO:root:360/2279 :: jolie.jolie)
# INFO:root:361/2279 :: semanticvectors.semanticvectors)
# INFO:root:362/2279 :: jenkinsci.remoting)
# INFO:root:363/2279 :: raphaeljolivet.java2typescript)
# INFO:root:364/2279 :: ToastShaman.dropwizard-auth-jwt)
# INFO:root:365/2279 :: julianhyde.sqlline)
# INFO:root:366/2279 :: OpenNMS.newts)
# INFO:root:367/2279 :: stealthly.dropwizard-kafka-http)
# INFO:root:368/2279 :: seancorfield.boot-new)
# INFO:root:369/2279 :: tobyweston.simple-excel)
# INFO:root:370/2279 :: fluent.fluent-logger-java)
# INFO:root:371/2279 :: cglib.cglib)
# INFO:root:372/2279 :: dhis2.dhis2-core)
# INFO:root:373/2279 :: dhowe.RiTa)
# INFO:root:374/2279 :: livingsocial.HiveSwarm)
# INFO:root:375/2279 :: allbegray.slack-api)
# INFO:root:376/2279 :: gliderlabs.herokuish)
# INFO:root:377/2279 :: cfwheels.cfwheels)
# INFO:root:378/2279 :: jakewins.brew)
# ERROR:maven:File is malformed: /home/agkortzis/git_repos/ICSR19/analysis/repositories_data/jakewins.brew.trees
# INFO:root:No modules to analyze: /home/agkortzis/git_repos/ICSR19/analysis/repositories_data/jakewins.brew.trees.
# INFO:root:379/2279 :: fearofcode.bateman)
# INFO:root:380/2279 :: netplex.json-smart-v2)
# INFO:root:No modules to analyze: /home/agkortzis/git_repos/ICSR19/analysis/repositories_data/netplex.json-smart-v2.trees.
# INFO:root:381/2279 :: authorjapps.zerocode)
# INFO:root:382/2279 :: OpenSextant.SolrTextTagger)
# INFO:root:383/2279 :: mguymon.model-citizen)
# INFO:root:384/2279 :: vbauer.caesar)
# INFO:root:385/2279 :: gazbert.BX-bot)
# INFO:root:386/2279 :: rapidoid.rapidoid)
# INFO:root:387/2279 :: jpmml.openscoring)
# INFO:root:388/2279 :: johnnian.Blog)
# INFO:root:389/2279 :: perf4j.perf4j)
# INFO:root:390/2279 :: UnquietCode.JState)
# INFO:root:No modules to analyze: /home/agkortzis/git_repos/ICSR19/analysis/repositories_data/UnquietCode.JState.trees.
# INFO:root:391/2279 :: Apicurio.apicurio-studio)
# INFO:root:392/2279 :: apache.commons-vfs)
# INFO:root:393/2279 :: jenkinsci.gitlab-plugin)
# INFO:root:No modules to analyze: /home/agkortzis/git_repos/ICSR19/analysis/repositories_data/jenkinsci.gitlab-plugin.trees.
# INFO:root:394/2279 :: kite-sdk.kite-examples)
# INFO:root:395/2279 :: Cue.greplin-exception-catcher)
# INFO:root:396/2279 :: 23.resumable.js)
# INFO:root:397/2279 :: wmr513.reactive)
# INFO:root:398/2279 :: akkumar.jreversepro)
# INFO:root:399/2279 :: gabrie-allaigre.sonar-gitlab-plugin)
# ERROR:maven:File is malformed: /home/agkortzis/git_repos/ICSR19/analysis/repositories_data/gabrie-allaigre.sonar-gitlab-plugin.trees
# INFO:root:No modules to analyze: /home/agkortzis/git_repos/ICSR19/analysis/repositories_data/gabrie-allaigre.sonar-gitlab-plugin.trees.
# INFO:root:400/2279 :: ddf.Minim)
# INFO:root:401/2279 :: toolbox4minecraft.amidst)
# INFO:root:402/2279 :: consulo.consulo)
# INFO:root:403/2279 :: banq.jdonframework)
# INFO:root:404/2279 :: gturri.aXMLRPC)
# INFO:root:405/2279 :: tools4j.unix4j)
# INFO:root:406/2279 :: usethesource.capsule)
# INFO:root:407/2279 :: blueconic.browscap-java)
# INFO:root:408/2279 :: clearthesky.apk-parser)
# INFO:root:409/2279 :: miwurster.spring-data-influxdb)
# INFO:root:410/2279 :: seratch.jslack)
# INFO:root:411/2279 :: jenkinsci.build-flow-plugin)
# INFO:root:No modules to analyze: /home/agkortzis/git_repos/ICSR19/analysis/repositories_data/jenkinsci
trees
# INFO:root:No modules to analyze: /home/agkortzis/git_repos/ICSR19/analysis/repositories_data/glycerine.goq.trees.
# INFO:root:460/2279 :: google.gcm)
# INFO:root:461/2279 :: pyloque.captain)
# INFO:root:462/2279 :: TestingForum.seleniumtestsframework)
# INFO:root:463/2279 :: maxmind.geoip-api-java)
# INFO:root:No modules to analyze: /home/agkortzis/git_repos/ICSR19/analysis/repositories_data/maxmind.geoip-api-java.trees.
# INFO:root:464/2279 :: abstractj.kalium)
# INFO:root:465/2279 :: mauersu.redis-admin)
# INFO:root:466/2279 :: FastBootWeixin.FastBootWeixin)
# INFO:root:467/2279 :: timgrossmann.StorageSystem)
# INFO:root:468/2279 :: phuonglh.vn.vitk)
# INFO:root:469/2279 :: traneio.future)
# INFO:root:470/2279 :: jdereg.json-io)
# INFO:root:No modules to analyze: /home/agkortzis/git_repos/ICSR19/analysis/repositories_data/jdereg.json-io.trees.
# INFO:root:471/2279 :: brettwooldridge.HikariJSON)
# INFO:root:No modules to analyze: /home/agkortzis/git_repos/ICSR19/analysis/repositories_data/brettwooldridge.HikariJSON.trees.
# INFO:root:472/2279 :: microbean.microbean-helm)
# INFO:root:473/2279 :: foo4u.spring-mvc-cache-control)
# INFO:root:474/2279 :: lukas-krecan.ShedLock)
# INFO:root:475/2279 :: wurstmeister.storm-kafka-0.8-plus-test)
# INFO:root:476/2279 :: stormning.spring-data-jpa-extra)
# INFO:root:477/2279 :: hfut-dmic.ContentExtractor)
# INFO:root:478/2279 :: RisingOak.jenkins-client)
# INFO:root:479/2279 :: Netflix-Skunkworks.zerotodocker)
# INFO:root:480/2279 :: soabase.soabase-halva)
# INFO:root:481/2279 :: awslabs.aws-device-farm-appium-tests-for-sample-app)
# INFO:root:482/2279 :: vsch.commonmark-java)
# INFO:root:483/2279 :: Cosium.spring-data-jpa-entity-graph)
# INFO:root:484/2279 :: QNJR-GROUP.EasyTransaction)
# INFO:root:485/2279 :: forge.core)
# INFO:root:486/2279 :: digitalfondue.lavagna)
# INFO:root:487/2279 :: mirkosertic.Bytecoder)
# INFO:root:488/2279 :: clearthesky.requests)
# INFO:root:489/2279 :: yahoo.mysql_perf_analyzer)
# INFO:root:490/2279 :: shibing624.similarity)
# INFO:root:491/2279 :: jonashackt.tutorial-soap-spring-boot-cxf)
# INFO:root:492/2279 :: RamosLi.dbay-apns-for-java)
# INFO:root:493/2279 :: Nepxion.Thunder)
# INFO:root:494/2279 :: joakime.android-apk-parser)
# INFO:root:495/2279 :: mono.sharpen)
# INFO:root:496/2279 :: zalando.tracer)
# INFO:root:497/2279 :: sendgrid.sendgrid-java)
# INFO:root:498/2279 :: Spirals-Team.librepair)
# INFO:root:499/2279 :: spotify.sparkey-java)
# INFO:root:500/2279 :: sakserv.hadoop-mini-clusters)
# INFO:root:501/2279 :: RishiGupta12.SerialPundit)
# INFO:root:502/2279 :: vertigo17.Cerberus)
# INFO:root:503/2279 :: junit-team.junit4)
# INFO:root:504/2279 :: AsuraTeam.monitor)
# INFO:root:505/2279 :: jenkinsci.github-oauth-plugin)
# INFO:root:No modules to analyze: /home/agkortzis/git_repos/ICSR19/analysis/repositories_data/jenkinsci.github-oauth-plugin.trees.
# INFO:root:506/2279 :: xSke.Pxls)
# INFO:root:507/2279 :: luhuiguo.chinese-utils)
# INFO:root:508/2279 :: tarql.tarql)
# INFO:root:509/2279 :: Devexperts.aprof)
# INFO:root:510/2279 :: cescoffier.my-vertx-first-app)
# INFO:root:511/2279 :: GoSimpleLLC.nbvcxz)
# INFO:root:512/2279 :: GoogleCloudPlatform.k8s-multicluster-ingress)
# INFO:root:513/2279 :: jcabi.jcabi-aspects)
# INFO:root:No modules to analyze: /home/agkortzis/git_repos/ICSR19/analysis/repositories_data/jcabi.jcabi-aspects.trees.
# INFO:root:514/2279 :: jenkinsci.jenkins)
# INFO:root:515/2279 :: GoogleContainerTools.skaffold)
# INFO:root:516/2279 :: Hervian.lambda-factory)
# INFO:root:517/2279 :: spring-cloud.spring-cloud-zookeeper)
# INFO:root:518/2279 :: FINRAOS.DataGenerator)
# INFO:root:519/2279 :: flapdoodle-oss.de.flapdoodle.embed.process)
# INFO:root:No modules to analyze: /home/agkortzis/git_repos/ICSR19/analysis/repositories_data/flapdoodle-oss.de.flapdoodle.embed.process.trees.
# INFO:root:520/2279 :: fallsea.spring-boot-starter-motan)
# INFO:root:521/2279 :: gravitee-io.gravitee-management-webui)
# INFO:root:No modules to analyze: /home/agkortzis/git_repos/ICSR19/analysis/repositories_data/gravitee-io.gravitee-management-webui.trees.
# INFO:root:522/2279 :: jklingsporn.vertx-jooq)
# INFO:root:523/2279 :: tamingtext.book)
# INFO:root:524/2279 :: codelibs.elasticsearch-auth)
# INFO:root:525/2279 :: profesorfalken.jPowerShell)
# INFO:root:526/2279 :: technomancy.s3-wagon-private)
# INFO:root:527/2279 :: oreonengine.oreon-engine)
# INFO:root:528/2279 :: ZhangJiupeng.AgentX)
# INFO:root:529/2279 :: cf-unik.unik)
# INFO:root:530/2279 :: ykameshrao.spring-mvc-angular-js-hibernate-bootstrap-java-single-page-jwt-auth-rest-api-webapp-framework)
# INFO:root:531/2279 :: zandero.rest.vertx)
# INFO:root:532/2279 :: spring-cloud-incubator.spring-cloud-kubernetes)
# INFO:root:533/2279 :: KostyaSha.github-integration-plugin)
# INFO:root:No modules to analyze: /home/agkortzis/git_repos/ICSR19/analysis/repositories_data/KostyaSha.github-integration-plugin.trees.
# INFO:root:534/2279 :: weamylady2.iOS_remote)
# INFO:root:535/2279 :: moszinet.BKKCrypt)
# INFO:root:536/2279 :: SonarQubeCommunity.sonar-build-breaker)
# ERROR:maven:File is malformed: /home/agkortzis/git_repos/ICSR19/analysis/repositories_data/SonarQubeCommunity.sonar-build-breaker.trees
# INFO:root:No modules to analyze: /home/agkortzis/git_repos/ICSR19/analysis/repositories_data/SonarQubeCommunity.sonar-build-breaker.trees.
# INFO:root:537/2279 :: davidmoten.rxjava2-jdbc)
# INFO:root:538/2279 :: tinify.tinify-java)
# INFO:root:No modules to analyze: /home/agkortzis/git_repos/ICSR19/analysis/repositories_data/tinify.tinify-java.trees.
# INFO:root:539/2279 :: awslabs.aws-scala-sdk)
# INFO:root:540/2279 :: benas.UnixStream)
# INFO:root:541/2279 :: sanity.quickml)
# INFO:root:542/2279 :: lastfm.musicbrainz-data)
# INFO:root:543/2279 :: flipkart-incubator.zjsonpatch)
# INFO:root:544/2279 :: contentful.vault)
# INFO:root:545/2279 :: charithe.kafka-junit)
# INFO:root:546/2279 :: alphatica.genotick)
# INFO:root:547/2279 :: jrkinley.storm-hbase)
# INFO:root:548/2279 :: HomeAdvisor.Kafdrop)
# INFO:root:549/2279 :: mapr-demos.kafka-sample-programs)
# INFO:root:550/2279 :: floragunncom.search-guard)
# INFO:root:551/2279 :: dmulloy2.ProtocolLib)
# INFO:root:552/2279 :: kohsuke.github-api)
# INFO:root:553/2279 :: asterisk-java.asterisk-java)
# INFO:root:554/2279 :: arangodb.arangodb-java-driver)
# INFO:root:555/2279 :: dokku.dokku)
# INFO:root:556/2279 :: usb4java.usb4java)
# INFO:root:557/2279 :: berndruecker.camunda-spring-boot-amqp-microservice-cloud-example)
# INFO:root:558/2279 :: monitorjbl.json-view)
# INFO:root:559/2279 :: perwendel.spark)
# INFO:root:No modules to analyze: /home/agkortzis/git_repos/ICSR19/analysis/repositories_data/perwendel.spark.trees.
# INFO:root:560/2279 :: Esri.spatial-framework-for-hadoop)
# INFO:root:561/2279 :: TFaga.KumuluzEE)
# INFO:root:562/2279 :: Steveice10.MCProtocolLib)
# INFO:root:563/2279 :: opentelecoms-org.jsmpp)
# INFO:root:564/2279 :: deegree.deegree3)
# INFO:root:565/2279 :: uncodecn.uncode-dal-all)
# INFO:root:566/2279 :: rtyley.android-screenshot-lib)
# INFO:root:567/2279 :: gradle.gradle)
# INFO:root:568/2279 :: andrewgaul.are-we-consistent-yet)
# INFO:root:569/2279 :: apache.commons-io)
# INFO:root:570/2279 :: smallnest.ZKRecipesByExample)
# INFO:root:571/2279 :: tillrohrmann.cep-monitoring)
# INFO:root:572/2279 :: nextcloud.android)
# INFO:root:573/2279 :: ihaolin.wechat)
# INFO:root:574/2279 :: kohsuke.com4j)
# INFO:root:575/2279 :: joelittlejohn.jsonschema2pojo)
# INFO:root:576/2279 :: spring-cloud.spring-cloud-commons)
# INFO:root:577/2279 :: yahoojapan.yisucon)
# INFO:root:578/2279 :: codecentric.jbehave-junit-runner)
# INFO:root:579/2279 :: usc.wechat-mp-sdk)
# INFO:root:580/2279 :: wuman.JReadability)
# INFO:root:581/2279 :: AmadeusITGroup.sonar-stash)
# ERROR:maven:File is malformed: /home/agkortzis/git_repos/ICSR19/analysis/repositories_data/AmadeusITGroup.sonar-stash.trees
# INFO:root:No modules to analyze: /home/agkortzis/git_repos/ICSR19/analysis/repositories_data/AmadeusITGroup.sonar-stash.trees.
# INFO:root:582/2279 :: noboomu.proteus)
# INFO:root:583/2279 :: AnujaK.restfiddle)
# INFO:root:584/2279 :: dhanji.loop)
# INFO:root:585/2279 :: suninformation.ymate-platform-v2)
# INFO:root:586/2279 :: mongodb-labs.socialite)
# INFO:root:587/2279 :: Free-Software-for-Android.NTPSync)
# INFO:root:588/2279 :: dain.snappy)
# INFO:root:589/2279 :: googleapis.google-cloud-java)
# INFO:root:590/2279 :: ozimov.spring-boot-email-tools)
# INFO:root:591/2279 :: smola.galimatias)
# INFO:root:592/2279 :: sebbrudzinski.Open-LaTeX-Studio)
# INFO:root:No modules to analyze: /home/agkortzis/git_repos/ICSR19/analysis/repositories_data/sebbrudzinski.Open-LaTeX-Studio.trees.
# INFO:root:593/2279 :: dustin.java-memcached-client)
# INFO:root:594/2279 :: awslabs.aws-apigateway-swagger-importer)
# INFO:root:595/2279 :: variflight.feeyo-redisproxy)
# INFO:root:596/2279 :: jponge.lzma-java)
# INFO:root:597/2279 :: yinlou.mltk)
# INFO:root:598/2279 :: junneyang.xxproject)
# INFO:root:599/2279 :: nicescale.docker-training)
# INFO:root:600/2279 :: winterbe.spring-kotlin-react-demo)
# INFO:root:601/2279 :: irmen.Pyrolite)
# INFO:root:602/2279 :: Graylog2.graylog2-alarmcallback-slack)
# INFO:root:603/2279 :: ha-jdbc.ha-jdbc)
# INFO:root:604/2279 :: nuke-build.nuke)
# INFO:root:605/2279 :: alibaba.dubbo)
# INFO:root:606/2279 :: DABSquared.gitlab-plugin)
# INFO:root:No modules to analyze: /home/agkortzis/git_repos/ICSR19/analysis/repositories_data/DABSquared.gitlab-plugin.trees.
# INFO:root:607/2279 :: ibm-messaging.mq-container)
# INFO:root:608/2279 :: kmtong.logback-redis-appender)
# INFO:root:609/2279 :: phoenixnap.springmvc-raml-plugin)
# ERROR:maven:File is malformed: /home/agkortzis/git_repos/ICSR19/analysis/repositories_data/phoenixnap.springmvc-raml-plugin.trees
# INFO:root:No modules to analyze: /home/agkortzis/git_repos/ICSR19/analysis/repositories_data/phoenixnap.springmvc-raml-plugin.trees.
# INFO:root:610/2279 :: chenlb.mmseg4j-solr)
# INFO:root:611/2279 :: circonus-labs.fq)
# INFO:root:612/2279 :: jberkel.pay-me)
# INFO:root:No modules to analyze: /home/agkortzis/git_repos/ICSR19/analysis/repositories_data/jberkel.pay-me.trees.
# INFO:root:613/2279 :: qmx.jitescript)
# INFO:root:614/2279 :: Swagger2Markup.swagger2markup-maven-plugin)
# ERROR:maven:File is malformed: /home/agkortzis/git_repos/ICSR19/analysis/repositories_data/Swagger2Markup.swagger2markup-maven-plugin.trees
# INFO:root:No modules to analyze: /home/agkortzis/git_repos/ICSR19/analysis/repositories_data/Swagger2Markup.swagger2markup-maven-plugin.trees.
# INFO:root:615/2279 :: korhner.asciimg)
# INFO:root:616/2279 :: priiduneemre.btcd-cli4j)
# INFO:root:617/2279 :: Microsoft.SparkCLR)
# INFO:root:618/2279 :: zeroturnaround.zt-zip)
# INFO:root:619/2279 :: mesosphere.hdfs)
# INFO:root:620/2279 :: camelinaction.camelinaction)
# INFO:root:621/2279 :: wkeyuan.DWSurvey)
# INFO:root:622/2279 :: os72.protoc-jar-maven-plugin)
# ERROR:maven:File is malformed: /home/agkortzis/git_repos/ICSR19/analysis/repositories_data/os72.protoc-jar-maven-plugin.trees
# INFO:root:No modules to analyze: /home/agkortzis/git_repos/ICSR19/analysis/repositories_data/os72.protoc-jar-maven-plugin.trees.
# INFO:root:623/2279 :: ehazlett.interlock)
# INFO:root:624/2279 :: gitbucket.markedj)
# INFO:root:625/2279 :: dbpedia.lookup)
# INFO:root:626/2279 :: jkrasnay.sqlbuilder)
# INFO:root:627/2279 :: cucumber.cucumber-jvm)
# INFO:root:628/2279 :: vbauer.jackdaw)
# INFO:root:629/2279 :: apache.commons-imaging)
# INFO:root:630/2279 :: subclipse.subclipse)
# INFO:root:No modules to analyze: /home/agkortzis/git_repos/ICSR19/analysis/repositories_data/subclipse.subclipse.trees.
# INFO:root:631/2279 :: redowl.swagger2markup-maven-plugin)
# ERROR:maven:File is malformed: /home/agkortzis/git_repos/ICSR19/analysis/repositories_data/redowl.swagger2markup-maven-plugin.trees
# INFO:root:No modules to analyze: /home/agkortzis/git_repos/ICSR19/analysis/repositories_data/redowl.swagger2markup-maven-plugin.trees.
# INFO:root:632/2279 :: starcwang.canal_mysql_elasticsearch_sync)
# INFO:root:633/2279 :: BuildStatic.AnvilGUI)
# INFO:root:634/2279 :: hailin0.sensitive-word-filter)
# INFO:root:635/2279 :: electronicarts.ea-agent-loader)
# INFO:root:636/2279 :: joshlong.service-registration-and-discovery)
# INFO:root:637/2279 :: monkeyk.oauth2-shiro)
# INFO:root:638/2279 :: howdyli.netty)
# INFO:root:639/2279 :: Eliteams.quick4j)
# INFO:root:640/2279 :: andrewgaul.s3proxy)
# INFO:root:641/2279 :: google.caliper)
# INFO:root:642/2279 :: momomoxiaoxi.security)
# INFO:root:643/2279 :: scireum.s3ninja)
# INFO:root:644/2279 :: nodyn.nodyn)
# INFO:root:645/2279 :: youseries.ureport)
# INFO:root:646/2279 :: jOOQ.jOOR)
# INFO:root:No modules to analyze: /home/agkortzis/git_repos/ICSR19/analysis/repositories_data/jOOQ.jOOR.trees.
# INFO:root:647/2279 :: JD-Software.JDeSurvey)
# INFO:root:648/2279 :: alphazero.jredis)
# INFO:root:649/2279 :: Yirendai.cicada)
# INFO:root:650/2279 :: rongcloud.server-sdk-java)
# INFO:root:651/2279 :: afonsof.jenkins-material-theme)
# INFO:root:No modules to analyze: /home/agkortzis/git_repos/ICSR19/analysis/repositories_data/afonsof.jenkins-material-theme.trees.
# INFO:root:652/2279 :: joestelmach.natty)
# INFO:root:653/2279 :: ltsopensource.light-task-scheduler)
# INFO:root:654/2279 :: spring-projects.spring-retry)
# INFO:root:655/2279 :: Southern-InfinityStudio.JMCCC)
# INFO:root:656/2279 :: lzkong1029.Yii2-Plus)
# INFO:root:657/2279 :: ZsoltSafrany.needle)
# INFO:root:658/2279 :: felayman.elasticsearch-full)
# INFO:root:659/2279 :: jmapper-framework.jmapper-core)
# INFO:root:660/2279 :: bytefish.FcmJava)
# INFO:root:661/2279 :: scala-ide.scala-ide)
# INFO:root:No modules to analyze: /home/agkortzis/git_repos/ICSR19/analysis/repositories_data/scala-ide.scala-ide.trees.
# INFO:root:662/2279 :: javatuples.javatuples)
# INFO:root:No modules to analyze: /home/agkortzis/git_repos/ICSR19/analysis/repositories_data/javatuples.javatuples.trees.
# INFO:root:663/2279 :: goldmansachs.gs-collections)
# INFO:root:664/2279 :: spotify.docker-client)
# INFO:root:665/2279 :: qikemi.UEditor-for-aliyun-OSS)
# INFO:root:666/2279 :: diegoceccarelli.json-wikipedia)
# INFO:root:667/2279 :: youseries.uflo)
# INFO:root:668/2279 :: linqs.psl)
# INFO:root:669/2279 :: sojamo.oscp5)
# INFO:root:670/2279 :: aws.aws-dynamodb-session-tomcat)
# INFO:root:671/2279 :: cschneider.Karaf-Tutorial)
# INFO:root:672/2279 :: almende.chap-links-library)
# INFO:root:673/2279 :: firery.mirs)
# INFO:root:674/2279 :: cucumber.cucumber-eclipse)
# INFO:root:No modules to analyze: /home/agkortzis/git_repos/ICSR19/analysis/repositories_data/cucumber.cucumber-eclipse.trees.
# INFO:root:675/2279 :: geosolutions-it.geoserver-manager)
# INFO:root:676/2279 :: Exslims.MercuryTrade)
# INFO:root:677/2279 :: jkuhnert.ognl)
# INFO:root:678/2279 :: cloudera.spark-timeseries)
# INFO:root:679/2279 :: spring-cloud-incubator.spring-cloud-etcd)
# INFO:root:680/2279 :: brooklyncentral.clocker)
# INFO:root:No modules to analyze: /home/agkortzis/git_repos/ICSR19/analysis/repositories_data/brooklyncentral.clocker.trees.
# INFO:root:681/2279 :: digidotcom.XBeeJavaLibrary)
# INFO:root:682/2279 :: atomashpolskiy.bt)
# INFO:root:683/2279 :: cognitect-labs.transducers-js)
# INFO:root:684/2279 :: timboudreau.nb-nodejs)
# INFO:root:No modules to analyze: /home/agkortzis/git_repos/ICSR19/analysis/repositories_data/timboudreau.nb-nodejs.trees.
# INFO:root:685/2279 :: twitter.hdfs-du)
# INFO:root:686/2279 :: jmrozanec.cron-utils)
# INFO:root:687/2279 :: apache.commons-collections)
# INFO:root:688/2279 :: nativelibs4java.JavaCL)
# INFO:root:689/2279 :: camunda.camunda-bpm-webapp)
# INFO:root:690/2279 :: medallia.Word2VecJava)
# INFO:root:691/2279 :: timgifford.maven-buildtime-extension)
# INFO:root:692/2279 :: thomasmueller.minperf)
# INFO:root:693/2279 :: flowable.flowable-engine)
# INFO:root:694/2279 :: arago.rike)
# INFO:root:695/2279 :: haoch.flink-siddhi)
# INFO:root:696/2279 :: japgolly.svg-android)
# INFO:root:697/2279 :: vdmeer.asciitable)
# INFO:root:698/2279 :: dschadow.JavaSecurity)
# INFO:root:699/2279 :: highj.highj)
# INFO:root:700/2279 :: square.mimecraft)
# INFO:root:701/2279 :: ThreeTen.threetenbp)
# INFO:root:702/2279 :: spring-cloud.spring-cloud-starters)
# INFO:root:No modules to analyze: /home/agkortzis/git_repos/ICSR19/analysis/repositories_data/spring-cloud.spring-cloud-starters.trees.
# INFO:root:703/2279 :: warmbreeze.sharded-jedis-sentinel-pool)
# INFO:root:704/2279 :: apache.olingo-odata4)
# INFO:root:705/2279 :: viant.endly)
# INFO:root:706/2279 :: romainr.hadoop-tutorials-examples)
# INFO:root:707/2279 :: webrtc.KITE)
# INFO:root:708/2279 :: mgodave.Jpcap)
# INFO:root:709/2279 :: bonigarcia.webdrivermanager)
# INFO:root:710/2279 :: jooby-project.jooby)
# INFO:root:711/2279 :: andrewgaul.modernizer-maven-plugin)
# INFO:root:712/2279 :: gardncl.elements-of-programming-interviews)
# INFO:root:713/2279 :: stanford-futuredata.macrobase)
# INFO:root:714/2279 :: cygri.pubby)
# INFO:root:715/2279 :: garbagemule.MobArena)
# INFO:root:716/2279 :: dataArtisans.flink-dataflow)
# INFO:root:717/2279 :: pac4j.spring-security-pac4j)
# INFO:root:718/2279 :: alibaba.wasp)
# INFO:root:719/2279 :: archimatetool.archi)
# INFO:root:No modules to analyze: /home/agkortzis/git_repos/ICSR19/analysis/repositories_data/archimatetool.archi.trees.
# INFO:root:720/2279 :: skyscreamer.JSONassert)
# INFO:root:721/2279 :: chocotan.lolibox)
# INFO:root:722/2279 :: elennick.retry4j)
# INFO:root:723/2279 :: CleverTap.apns-http2)
# INFO:root:724/2279 :: smallnest.Jax-RS-Performance-Comparison)
# INFO:root:725/2279 :: decorators-squad.camel)
# INFO:root:726/2279 :: Anchormen.sql4es)
# INFO:root:727/2279 :: mrin9.Angular2_SpringBoot)
# INFO:root:728/2279 :: fang-yan-peng.eagle)
# INFO:root:729/2279 :: jprante.elasticsearch-skywalker)
# INFO:root:730/2279 :: spotify.annoy-java)
# INFO:root:731/2279 :: jenkinsci.docker-plugin)
# INFO:root:No modules to analyze: /home/agkortzis/git_repos/ICSR19/analysis/repositories_data/jenkinsci.docker-plugin.trees.
# INFO:root:732/2279 :: lcg0124.bootdo)
# INFO:root:733/2279 :: Eneco.kafka-connect-twitter)
# INFO:root:734/2279 :: restic.rest-server)
# INFO:root:735/2279 :: Webtrends.wookiee)
# INFO:root:736/2279 :: yeleaveszi.Play-Videos-In-HDFS)
# INFO:root:737/2279 :: Noahs-ARK.semafor)
# INFO:root:738/2279 :: qlik-oss.server-side-extension)
# INFO:root:739/2279 :: spring-cloud.spring-cloud-sleuth)
# INFO:root:740/2279 :: locationtech.geowave)
# INFO:root:741/2279 :: gamlerhart.adbcj)
# INFO:root:742/2279 :: kevinsawicki.http-request)
# INFO:root:743/2279 :: cloudml.zen)
# INFO:root:No modules to analyze: /home/agkortzis/git_repos/ICSR19/analysis/repositories_data/cloudml.zen.trees.
# ...
# INFO:root:2010/2279 :: pgjdbc.pgjdbc)
# INFO:root:No modules to analyze: /home/agkortzis/git_repos/ICSR19/analysis/repositories_data/pgjdbc.pgjdbc.trees.
# INFO:root:2011/2279 :: EsotericSoftware.minlog)
# INFO:root:No modules to analyze: /home/agkortzis/git_repos/ICSR19/analysis/repositories_data/EsotericSoftware.minlog.trees.
# INFO:root:2012/2279 :: red6.pdfcompare)
# INFO:root:2013/2279 :: sheepmen.Spring-Boot-Blog)
# INFO:root:2014/2279 :: wix.wix-embedded-mysql)
# INFO:root:2015/2279 :: estatio.estatio)
# INFO:root:2016/2279 :: USCDataScience.sparkler)
# INFO:root:2017/2279 :: zchee.clang-server)
# INFO:root:No modules to analyze: /home/agkortzis/git_repos/ICSR19/analysis/repositories_data/zchee.clang-server.trees.
# INFO:root:2018/2279 :: Pablissimo.SonarTsPlugin)
# ERROR:maven:File is malformed: /home/agkortzis/git_repos/ICSR19/analysis/repositories_data/Pablissimo.SonarTsPlugin.trees
# INFO:root:No modules to analyze: /home/agkortzis/git_repos/ICSR19/analysis/repositories_data/Pablissimo.SonarTsPlugin.trees.
# INFO:root:2019/2279 :: logsniffer.logsniffer)
# INFO:root:2020/2279 :: deeplearning4j.nd4j)
# INFO:root:2021/2279 :: hgoebl.DavidWebb)
# INFO:root:2022/2279 :: vidageek.mirror)
# INFO:root:2023/2279 :: droolsjbpm.optaplanner)
# INFO:root:2024/2279 :: spotify.spydra)
# INFO:root:2025/2279 :: nghialv.promviz)
# INFO:root:2026/2279 :: ThreeTen.threeten-extra)
# INFO:root:2027/2279 :: skavanagh.KeyBox-OpenShift)
# INFO:root:2028/2279 :: NationalSecurityAgency.timely)
# INFO:root:2029/2279 :: Aconex.scrutineer)
# INFO:root:2030/2279 :: cucumber.cucumber)
# INFO:root:2031/2279 :: symphoniacloud.lambda-monitoring)
# INFO:root:2032/2279 :: jacobwgillespie.heroku-minecraft)
# INFO:root:2033/2279 :: crawler-commons.crawler-commons)
# INFO:root:2034/2279 :: actframework.actframework)
# INFO:root:2035/2279 :: Watson-Explorer.wex-wdc-integration-samples)
# INFO:root:2036/2279 :: pires.obd-java-api)
# INFO:root:2037/2279 :: sohutv.cachecloud)
# INFO:root:2038/2279 :: Glamdring.computoser)
# INFO:root:2039/2279 :: ESAPI.esapi-java)
# INFO:root:2040/2279 :: cyrilmottier.GreenDroid)
# INFO:root:2041/2279 :: slyak.spring-data-jpa-extra)
# INFO:root:2042/2279 :: jpmml.jpmml-evaluator)
# INFO:root:2043/2279 :: philipsorst.angular-rest-springsecurity)
# INFO:root:2044/2279 :: Stratio.Decision)
# INFO:root:2045/2279 :: GoogleCloudPlatform.cloud-bigtable-examples)
# INFO:root:2046/2279 :: MaterialPrime.material-prime)
# INFO:root:2047/2279 :: taycaldwell.riot-api-java)
# INFO:root:2048/2279 :: RedisLabs.redis-quartz)
# INFO:root:2049/2279 :: thymeleaf.thymeleafexamples-layouts)
# INFO:root:2050/2279 :: kotlinx.kotlinx.html)
# INFO:root:2051/2279 :: fstab.promagent)
# INFO:root:2052/2279 :: vulhub.vulhub)
# INFO:root:2053/2279 :: lukeiwanski.tensorflow)
# INFO:root:2054/2279 :: mvetsch.JWT4B)
# INFO:root:2055/2279 :: GIScience.openrouteservice-core)
# INFO:root:2056/2279 :: 7040210.SuperBoot)
# INFO:root:2057/2279 :: google.open-location-code)
# INFO:root:2058/2279 :: finn-no.xss-html-filter)
# INFO:root:2059/2279 :: forcedotcom.SalesforceCanvasFrameworkSDK)
# INFO:root:2060/2279 :: jruby.joni)
# INFO:root:2061/2279 :: awslabs.dynamodb-import-export-tool)
# INFO:root:2062/2279 :: robinst.git-merge-repos)
# INFO:root:2063/2279 :: rithms.riot-api-java)
# INFO:root:2064/2279 :: wso2.siddhi)
# INFO:root:2065/2279 :: statedecoded.statedecoded)
# INFO:root:2066/2279 :: twitter.hpack)
# INFO:root:2067/2279 :: csob.paymentgateway)
# INFO:root:2068/2279 :: searchbox-io.Jest)
# INFO:root:2069/2279 :: HadoopGenomics.Hadoop-BAM)
# INFO:root:2070/2279 :: tlaukkan.zigbee4java)
# INFO:root:2071/2279 :: geoscript.geoscript-js)
# INFO:root:2072/2279 :: OpenConext.Mujina)
# INFO:root:2073/2279 :: Berico-Technologies.CLAVIN)
# INFO:root:2074/2279 :: spring-cloud-samples.aws-refapp)
# INFO:root:2075/2279 :: jcabi.jcabi-http)
# INFO:root:2076/2279 :: xiaxiaocao.apk-parser)
# INFO:root:2077/2279 :: awslabs.amazon-sqs-java-messaging-lib)
# INFO:root:2078/2279 :: zalando.problem-spring-web)
# INFO:root:2079/2279 :: wvengen.proguard-maven-plugin)
# ERROR:maven:File is malformed: /home/agkortzis/git_repos/ICSR19/analysis/repositories_data/wvengen.proguard-maven-plugin.trees
# INFO:root:No modules to analyze: /home/agkortzis/git_repos/ICSR19/analysis/repositories_data/wvengen.proguard-maven-plugin.trees.
# INFO:root:2080/2279 :: dblock.jenkins-ansicolor-plugin)
# INFO:root:No modules to analyze: /home/agkortzis/git_repos/ICSR19/analysis/repositories_data/dblock.jenkins-ansicolor-plugin.trees.
# INFO:root:2081/2279 :: Mashape.unirest-java)
# INFO:root:2082/2279 :: qcloudsms.qcloudsms_java)
# INFO:root:2083/2279 :: spring-projects.spring-data-examples)
# INFO:root:2084/2279 :: twitter.whiskey)
# INFO:root:2085/2279 :: groupon.odo)
# INFO:root:2086/2279 :: tcurdt.jdeb)
# ERROR:maven:File is malformed: /home/agkortzis/git_repos/ICSR19/analysis/repositories_data/tcurdt.jdeb.trees
# INFO:root:No modules to analyze: /home/agkortzis/git_repos/ICSR19/analysis/repositories_data/tcurdt.jdeb.trees.
# INFO:root:2087/2279 :: tjake.rbm-dbn-mnist)
# INFO:root:2088/2279 :: Vhati.ftl-profile-editor)
# INFO:root:2089/2279 :: square.otto)
# INFO:root:2090/2279 :: jkcclemens.khttp)
# INFO:root:2091/2279 :: jsoverson.todomvc)
# INFO:root:2092/2279 :: sgsinclair.Voyant)
# INFO:root:2093/2279 :: ggrandes.bouncer)
# INFO:root:2094/2279 :: bndtools.bndtools)
# INFO:root:2095/2279 :: Sarwat.GeoSpark)
# INFO:root:2096/2279 :: square.burst)
# INFO:root:2097/2279 :: dibbhatt.kafka-spark-consumer)
# INFO:root:2098/2279 :: coveo.fmt-maven-plugin)
# ERROR:maven:File is malformed: /home/agkortzis/git_repos/ICSR19/analysis/repositories_data/coveo.fmt-maven-plugin.trees
# INFO:root:No modules to analyze: /home/agkortzis/git_repos/ICSR19/analysis/repositories_data/coveo.fmt-maven-plugin.trees.
# INFO:root:2099/2279 :: zalando.problem)
# INFO:root:2100/2279 :: atlassian.commonmark-java)
# INFO:root:2101/2279 :: SAP.ui5-inspector)
# INFO:root:No modules to analyze: /home/agkortzis/git_repos/ICSR19/analysis/repositories_data/SAP.ui5-inspector.trees.
# INFO:root:2102/2279 :: jonnyzzz.TeamCity.Node)
# INFO:root:2103/2279 :: kpelykh.docker-java)
# INFO:root:2104/2279 :: eed3si9n.scalaxb)
# ERROR:maven:File is malformed: /home/agkortzis/git_repos/ICSR19/analysis/repositories_data/eed3si9n.scalaxb.trees
# INFO:root:No modules to analyze: /home/agkortzis/git_repos/ICSR19/analysis/repositories_data/eed3si9n.scalaxb.trees.
# INFO:root:2105/2279 :: roncoo.roncoo-jui-springboot)
# INFO:root:2106/2279 :: eustas.CafeUndZopfli)
# INFO:root:2107/2279 :: pentaho.pentaho-kettle)
# INFO:root:2108/2279 :: Stratio.spark-mongodb)
# INFO:root:2109/2279 :: jkransen.framboos)
# INFO:root:2110/2279 :: perlundq.yajsync)
# INFO:root:2111/2279 :: zeromq.jeromq)
# INFO:root:2112/2279 :: fommil.matrix-toolkits-java)
# INFO:root:2113/2279 :: devnied.EMV-NFC-Paycard-Enrollment)
# INFO:root:2114/2279 :: spring-cloud.spring-cloud-stream-app-starters)
# INFO:root:2115/2279 :: snakerflow.snakerflow)
# INFO:root:2116/2279 :: yegor256.cactoos)
# INFO:root:2117/2279 :: DeemOpen.zkui)
# INFO:root:2118/2279 :: kennycason.kumo)
# INFO:root:2119/2279 :: apache.orc)
# INFO:root:2120/2279 :: att.XACML)
# INFO:root:2121/2279 :: GoogleCloudPlatform.cloud-dataproc)
# INFO:root:2122/2279 :: springuni.springuni-particles)
# INFO:root:2123/2279 :: javamonkey.beetl2.0)
# INFO:root:2124/2279 :: playn.playn)
# INFO:root:2125/2279 :: SalesforceFoundation.ApexDoc)
# INFO:root:2126/2279 :: simpligility.android-maven-plugin)
# ERROR:maven:File is malformed: /home/agkortzis/git_repos/ICSR19/analysis/repositories_data/simpligility.android-maven-plugin.trees
# INFO:root:No modules to analyze: /home/agkortzis/git_repos/ICSR19/analysis/repositories_data/simpligility.android-maven-plugin.trees.
# INFO:root:2127/2279 :: goldmansachs.reladomo)
# INFO:root:2128/2279 :: rkalla.imgscalr)
# INFO:root:2129/2279 :: Omertron.api-themoviedb)
# INFO:root:2130/2279 :: mrsqueeze.spark-hash)
# INFO:root:2131/2279 :: avianey.androidsvgdrawable-plugin)
# INFO:root:2132/2279 :: vakinge.jeesuite-libs)
# INFO:root:2133/2279 :: brunocvcunha.instagram4j)
# INFO:root:2134/2279 :: asofdate.batch-scheduler)
# INFO:root:2135/2279 :: mbreese.couchdb4j)
# INFO:root:2136/2279 :: SeleniumHQ.htmlunit-driver)
# INFO:root:2137/2279 :: horrorho.InflatableDonkey)
# INFO:root:2138/2279 :: retrostreams.android-retrostreams)
# INFO:root:2139/2279 :: oreon3D.Oreon.Engine-OpenGL-Java)
# INFO:root:2140/2279 :: penberg.falcon)
# INFO:root:2141/2279 :: cloudera.hue)
# INFO:root:No modules to analyze: /home/agkortzis/git_repos/ICSR19/analysis/repositories_data/cloudera.hue.trees.
# INFO:root:2142/2279 :: Tanaguru.Contrast-Finder)
# INFO:root:2143/2279 :: vkostyukov.la4j)
# INFO:root:2144/2279 :: spring-projects.aws-maven)
# INFO:root:2145/2279 :: jenkinsci.amazon-ecs-plugin)
# INFO:root:No modules to analyze: /home/agkortzis/git_repos/ICSR19/analysis/repositories_data/jenkinsci.amazon-ecs-plugin.trees.
# INFO:root:2146/2279 :: Raudius.Pushraven)
# INFO:root:2147/2279 :: jmacglashan.burlap)
# INFO:root:2148/2279 :: bazhenov.groovy-shell-server)
# INFO:root:2149/2279 :: twitter.iago)
# INFO:root:2150/2279 :: dima767.inspektr)
# INFO:root:2151/2279 :: spatial4j.spatial4j)
# INFO:root:No modules to analyze: /home/agkortzis/git_repos/ICSR19/analysis/repositories_data/spatial4j.spatial4j.trees.
# INFO:root:2152/2279 :: skuid.helm-value-store)
# INFO:root:2153/2279 :: mfornos.humanize)
# INFO:root:2154/2279 :: keepcosmos.beanmother)
# INFO:root:2155/2279 :: songgc.display-advertising-challenge)
# INFO:root:2156/2279 :: OpenFeign.feign-form)
# INFO:root:2157/2279 :: elasticjob.elastic-job)
# INFO:root:2158/2279 :: easymock.objenesis)
# INFO:root:2159/2279 :: benas.jPopulator)
# INFO:root:2160/2279 :: krajj7.BotHack)
# INFO:root:2161/2279 :: derjust.spring-data-dynamodb)
# INFO:root:2162/2279 :: wwadge.bonecp)
# INFO:root:2163/2279 :: mongodb-labs.hvdf)
# INFO:root:2164/2279 :: BotMill.fb-botmill)
# INFO:root:2165/2279 :: mesos.storm)
# INFO:root:2166/2279 :: szegedi.dynalink)
# INFO:root:2167/2279 :: osrg.namazu)
# INFO:root:2168/2279 :: hmsonline.cassandra-indexing)
# INFO:root:2169/2279 :: davidmoten.rxjava-extras)
# INFO:root:2170/2279 :: Upplication.Amazon-S3-FileSystem-NIO2)
# INFO:root:2171/2279 :: rmuller.infomas-asl)
# INFO:root:No modules to analyze: /home/agkortzis/git_repos/ICSR19/analysis/repositories_data/rmuller.infomas-asl.trees.
# INFO:root:2172/2279 :: dwdyer.uncommons-maths)
# INFO:root:2173/2279 :: thechunknetwork.RedisBungee)
# INFO:root:2174/2279 :: appcelerator.amp)
# INFO:root:2175/2279 :: srcclr.bughunt)
# INFO:root:2176/2279 :: code4craft.tiny-spring)
# INFO:root:2177/2279 :: danielwegener.logback-kafka-appender)
# INFO:root:2178/2279 :: tburch.jsonblob)
# INFO:root:2179/2279 :: chenlb.mmseg4j-core)
# INFO:root:2180/2279 :: ClearTK.cleartk)
# INFO:root:2181/2279 :: messenger4j.messenger4j)
# INFO:root:2182/2279 :: to2mbn.JMCCC)
# INFO:root:2183/2279 :: manuelbua.libgdx-contribs)
# INFO:root:2184/2279 :: 94fzb.zrlog)
# INFO:root:2185/2279 :: poetix.octarine)
# INFO:root:2186/2279 :: bguerout.jongo)
# INFO:root:2187/2279 :: open-korean-text.open-korean-text)
# INFO:root:2188/2279 :: jOOQ.jOOX)
# INFO:root:No modules to analyze: /home/agkortzis/git_repos/ICSR19/analysis/repositories_data/jOOQ.jOOX.trees.
# INFO:root:2189/2279 :: ACINQ.bitcoin-lib)
# INFO:root:2190/2279 :: apache.commons-compress)
# INFO:root:2191/2279 :: bonigarcia.dualsub)
# INFO:root:2192/2279 :: ordina-jworks.microservices-dashboard)
# INFO:root:2193/2279 :: mertakdut.EpubParser)
# INFO:root:2194/2279 :: aadnk.ProtocolLib)
# INFO:root:2195/2279 :: sorm.sorm)
# INFO:root:2196/2279 :: JakeWharton.DiskLruCache)
# INFO:root:2197/2279 :: hankcs.HanLP)
# INFO:root:2198/2279 :: sebarmeli.Selenium2-Java-QuickStart-Archetype)
# INFO:root:2199/2279 :: zhegexiaohuozi.SeimiCrawler)
# INFO:root:2200/2279 :: snakerflow.snaker-web)
# INFO:root:2201/2279 :: xujeff.tianti)
# INFO:root:2202/2279 :: aboutsip.pkts)
# INFO:root:2203/2279 :: JodaOrg.joda-convert)
# INFO:root:2204/2279 :: pac4j.play-pac4j)
# INFO:root:2205/2279 :: DataSketches.sketches-core)
# INFO:root:2206/2279 :: allure-framework.allure-core)
# INFO:root:2207/2279 :: BrightTag.kafkameter)
# INFO:root:2208/2279 :: dangdangdotcom.sharding-jdbc)
# INFO:root:2209/2279 :: armzilla.amazon-echo-ha-bridge)
# INFO:root:2210/2279 :: brettwooldridge.NuProcess)
# INFO:root:No modules to analyze: /home/agkortzis/git_repos/ICSR19/analysis/repositories_data/brettwooldridge.NuProcess.trees.
# INFO:root:2211/2279 :: malensek.jbsdiff)
# INFO:root:2212/2279 :: SparkTC.stocator)
# INFO:root:2213/2279 :: FasterXML.jackson-jr)
# INFO:root:2214/2279 :: AgNO3.jcifs-ng)
# INFO:root:No modules to analyze: /home/agkortzis/git_repos/ICSR19/analysis/repositories_data/AgNO3.jcifs-ng.trees.
# INFO:root:2215/2279 :: nuclio.nuclio)
# INFO:root:2216/2279 :: dropwizard.dropwizard)
# INFO:root:2217/2279 :: pedrovgs.Algorithms)
# INFO:root:2218/2279 :: hankcs.TextRank)
# INFO:root:2219/2279 :: bitstorm.Wicket-tutorial-examples)
# INFO:root:2220/2279 :: ctripcorp.cornerstone)
# INFO:root:2221/2279 :: abel533.Mapper)
# INFO:root:2222/2279 :: hypercube1024.firefly)
# INFO:root:2223/2279 :: NewLisper.yin)
# INFO:root:2224/2279 :: tkaczmarzyk.specification-arg-resolver)
# INFO:root:2225/2279 :: kohsuke.groovy-sandbox)
# INFO:root:2226/2279 :: nathanielc.morgoth)
# INFO:root:2227/2279 :: julianhyde.linq4j)
# INFO:root:2228/2279 :: awslabs.aws-codedeploy-plugin)
# INFO:root:No modules to analyze: /home/agkortzis/git_repos/ICSR19/analysis/repositories_data/awslabs.aws-codedeploy-plugin.trees.
# INFO:root:2229/2279 :: tongpi.basicOCR)
# INFO:root:2230/2279 :: glyptodon.guacamole-client)
# INFO:root:2231/2279 :: zalando-stups.tokens)
# INFO:root:2232/2279 :: williewheeler.kite)
# INFO:root:2233/2279 :: clohfink.RendezvousHash)
# INFO:root:2234/2279 :: NCR-CoDE.QuickTheories)
# INFO:root:2235/2279 :: AdRoll.cantor)
# INFO:root:2236/2279 :: apache.httpcore)
# INFO:root:2237/2279 :: jirutka.spring-rest-exception-handler)
# INFO:root:2238/2279 :: Azure.azure-event-hubs)
# INFO:root:2239/2279 :: cisco.elsy)
# INFO:root:2240/2279 :: viritin.viritin)
# INFO:root:No modules to analyze: /home/agkortzis/git_repos/ICSR19/analysis/repositories_data/viritin.viritin.trees.
# INFO:root:2241/2279 :: oktadeveloper.jhipster-microservices-example)
# INFO:root:2242/2279 :: beeva.beeva-best-practices)
# INFO:root:2243/2279 :: greenmail-mail-test.greenmail)
# INFO:root:2244/2279 :: j256.simplemagic)
# INFO:root:2245/2279 :: spencergibb.spring-cloud-vault-config)
# INFO:root:2246/2279 :: rubenlagus.TelegramApi)
# INFO:root:2247/2279 :: raydac.mvn-golang)
# INFO:root:2248/2279 :: apache.maven)
# INFO:root:2249/2279 :: google.gwtmockito)
# INFO:root:2250/2279 :: cmeza20.spring-data-generator)
# ERROR:maven:File is malformed: /home/agkortzis/git_repos/ICSR19/analysis/repositories_data/cmeza20.spring-data-generator.trees
# INFO:root:No modules to analyze: /home/agkortzis/git_repos/ICSR19/analysis/repositories_data/cmeza20.spring-data-generator.trees.
# INFO:root:2251/2279 :: java-webbee.webBee)
# INFO:root:2252/2279 :: documents4j.documents4j)
# INFO:root:2253/2279 :: jitsi.jigasi)
# INFO:root:2254/2279 :: googleads.aw-reporting)
# INFO:root:2255/2279 :: vivekn.autocomplete)
# INFO:root:2256/2279 :: spring-projects.spring-plugin)
# INFO:root:2257/2279 :: vdurmont.emoji-java)
# INFO:root:2258/2279 :: lihengming.java-codes)
# INFO:root:2259/2279 :: dangdangdotcom.config-toolkit)
# INFO:root:2260/2279 :: xpqiu.fnlp)
# INFO:root:2261/2279 :: Cue.greplin-lucene-utils)
# INFO:root:2262/2279 :: SAP.openui5)
# INFO:root:2263/2279 :: vert-x3.vertx-examples)
# INFO:root:2264/2279 :: atteo.evo-inflector)
# INFO:root:2265/2279 :: apache.commons-lang)
# INFO:root:2266/2279 :: qq254963746.light-task-scheduler)
# INFO:root:2267/2279 :: solarwinds.OrionSDK)
# INFO:root:2268/2279 :: xiaxiaocao.requests)
# INFO:root:2269/2279 :: 1994.ssm-scaffold)
# INFO:root:2270/2279 :: mpusher.mpush)
# INFO:root:2271/2279 :: unidal.cat2)
# INFO:root:2272/2279 :: GideonLeGrange.mikrotik-java)
# INFO:root:2273/2279 :: creactiviti.piper)
# INFO:root:2274/2279 :: log4mongo.log4mongo-java)
# INFO:root:2275/2279 :: PyvesB.AdvancedAchievements)
# INFO:root:2276/2279 :: tomsik68.mclauncher-api)
# INFO:root:2277/2279 :: microprofile.microprofile-config)
# INFO:root:2278/2279 :: alibaba.java-dns-cache-manipulator)
# Found 36 projects as dependencies
# Finished at :: 2019-10-22 22:42:07.169318
